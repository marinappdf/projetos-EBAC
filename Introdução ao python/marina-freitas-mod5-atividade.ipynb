# %%
# 3) Implemente ao menos 4 operações matemáticas em seu código;
# 5) Utilize o comando 'print' para exibir o resultado da operação matemática.
def somar(a,b):
  print("A soma de a e b é igual a " + str(a + b))

def subtrair(a , b):
  print("A subtração de a por b é igual a " + str(a - b))

def dividir(a,b):
  print("A divisão de a por b é igual a " + str(a/ b))

def multiplicar(a,b):
  print("A multiplicação de a e b é igual a " +  str(a*b))

print("Boas vindas a Calculadora!")

# 4) Adicione um laço de repetição ou uma condicional.
sair = False
while (not sair):

    # 1) Utilize o comando 'input' para receber ao menos 2 números de entrada do usuário;
    # 2) Converta os valores recebidos pelo usuário para número inteiro (int) ou ponto flutuante (float)
    a = float(input('Escreva um números'))
    b = float(input('Escreva mais um números'))
    print('Os números escolhidos são: a = '+ str(a) +" b = " + str(b))
    # 4) Adicione um laço de repetição ou uma condicional.
    entrada = input('Indique qual operação deseja realizar: +. -, * ou /. Para sair digite "sair".')
    

    
   
    if (entrada == '+'):
        somar(a,b)
    elif (entrada == '-'):
        subtrair(a,b)
    elif (entrada == '*'):
        multiplicar(a,b)
    elif (entrada == '/'):
        dividir(a,b)
    elif (entrada.lower() == "sair"):
        sair = True
        print("Encerrando o programa. . . ")
        break;
    else :
        print('Entrada inválida, tente de novo.')
# Out:
# Boas vindas a Calculadora!
# Escreva um números 5
# Escreva mais um números 5
# Os números escolhidos são: a = 5.0 b = 5.0
# Indique qual operação deseja realizar: +. -, * ou /. Para sair digite "sair". sair
# Encerrando o programa. . .
